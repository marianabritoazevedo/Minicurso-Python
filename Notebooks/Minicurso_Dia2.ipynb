# %% [markdown]
# # Introdução à programação com Python 💻
#
# ### **Dia 2 - Avançando com Python**
#
# Este notebook tem como objetivo dar continuidade aos aprendizados de programação com a linguagem de programação **Python**. Aqui, iremos fazer exercícios dos seguintes conteúdos:
#
# *   Listas e matrizes
# *   Acessando elementos em listas e matrizes
# *   Estruturas de repetição
# *   Trabalhando com tabelas: biblioteca Pandas
# *   Trabalhando com gráficos: biblioteca Plotly

# %% [markdown]
# ## Parte 1: Listas

# %% [markdown]
# Anteriormente, estávamos gravando em variáveis apenas uma única informação, fosse ela um número ou um texto. Agora, em uma única variável, podemos guardar **várias informações**, podendo essas informações ser no formato de **listas**.
#
# Abaixo, podemos ver um exemplo da diferença de uma variável do tipo string para uma lista. Enquanto a variável **nome** guarda apenas uma informação, a variável **nomes** é uma lista que guarda 4 informações.

# %% [markdown]
# ![lista.png](data:image/png;base64,...)

# %% [markdown]
# Para declarar uma lista em Python, utilizamos os colchetes `[]` e colocamos todas as informações que queremos guardar dentro deles, separando-as com vírgula.

# %% [markdown]
# ### **Exemplo 1**: Listando os alunos de uma sala
#
# Levando em consideração a imagem da explicação anterior, vamos armazenar o nome de todos os alunos presentes na turma de Geografia do semestre de 2023.1 da UFRN. Abaixo, seguem os nomes de todos os alunos:
#
# *   Clarisse
# *   Laura
# *   Melissa
# *   Joana

# %%
lista_alunos = ['Clarisse', 'Laura', 'Melissa', 'Joana']
print(lista_alunos)

# %% [markdown]
# ### **Exercício 1**: Armazenando informações das regiões brasileiras
#
# Para fazer um estudo das regiões brasileiras, crie as seguintes listas para armazenar as seguintes informações:
#
# *   `nome_regioes`: deve conter os nomes das 5 regiões do Brasil;
# *   `temp_regioes`: deve contar a temperatura média das regiões brasileiras. Considere o Norte como 27°C, o Nordeste como 30°C, o Centro Oeste como 25°C, o Sudeste como 23°C e o Sul como 21°C.
#
# Ao final, mostre esses valores na tela com a função `print()`

# %%
# Escreva seu código AQUI

# %% [markdown]
# Uma característica importante das listas é que também conseguimos **acessar** individualmente as suas informações com base em um **índice**. Basicamente, o índice consiste em um número para identificar a **posição** de um elemento em uma lista, e na programação, sempre começamos com o valor 0 para o índice do primeiro elemento. Na figura abaixo, para acessar o nome **Luíza**, deve-se utilizar o seguinte código:
#
# ```
# nomes[2]
# ```

# %% [markdown]
# ![posicao-vetor.png](data:image/png;base64,...)

# %% [markdown]
# ### **Exercício 2**: acessando nomes de países
#
# Abaixo, segue uma lista com todos os países da América do Sul, com as informações guardadas na lista `paises_america_sul`. Abaixo, observa-se uma listagem com a quantidade aproximada de habitantes de cada um desses países:
#
# *       Argentina: Aproximadamente 45,4 milhões de habitantes.
# *       Bolívia: Aproximadamente 11,8 milhões de habitantes.
# *       Brasil: Aproximadamente 213,9 milhões de habitantes.
# *       Chile: Aproximadamente 19,1 milhões de habitantes.
# *       Colômbia: Aproximadamente 50,3 milhões de habitantes.
# *       Equador: Aproximadamente 17,8 milhões de habitantes.
# *       Guiana: Aproximadamente 790 mil habitantes.
# *       Paraguai: Aproximadamente 7,3 milhões de habitantes.
# *       Peru: Aproximadamente 33,8 milhões de habitantes.
# *       Suriname: Aproximadamente 591 mil habitantes.
# *       Uruguai: Aproximadamente 3,5 milhões de habitantes.
# *       Venezuela: Aproximadamente 28,4 milhões de habitantes.
#
# Com base nessas informações, crie outra lista chamada `paises_acima_15_milhoes` apenas com os países que possuem mais de 15 milhões de habitantes. Ao final, mostre essa informação na tela com a função `print()`

# %%
paises_america_sul = ['Bolívia', 'Guiana', 'Paraguai', 'Argentina', 'Brasil', 'Chile',  'Colômbia', 'Equador', 'Peru', 'Venezuela', 'Suriname', 'Uruguai']
# Continue o código AQUI

# %% [markdown]
# ## Parte 2: Matrizes

# %% [markdown]
# De forma semelhante às listas, as **matrizes** também conseguem armazenar mais de uma informação em uma variável. Entretanto, elas são capazes de armazenar as informações em forma de **tabela**, contendo informações dispostas em linhas e colunas.

# %% [markdown]
# ![matriz.png](data:image/png;base64,...)

# %% [markdown]
# ### **Exemplo 2**: Criando e acessando elementos de uma matriz
#
# Crie a matriz mostrada na imagem anterior e imprima na tela o número 80.

# %%
numeros = [[10, 20, 30],
           [40, 50, 60],
           [70, 80, 90]]
numero_80 = numeros[2][1]
print(numero_80)

# %% [markdown]
# Como você pode perceber com este exemplo, a matriz funciona como uma lista de listas no Python, em que cada uma das listas internas é separada com uma vírgula.

# %% [markdown]
# ### **Exercício 3**: Criando uma matriz para armazenar informações de cidades
#
# Cada coluna da matriz conterá informações de uma cidade, e cada linha, uma informação específica sobre àquela cidade. Construa uma matriz com o seguinte formato:
#
# *   Linha 0: nome da cidade
# *   Linha 1: quantidade de habitantes da cidade;
# *   Linha 2: área da cidade em km²;
# *   Linha 3: temperatura média da cidade em graus Celsius.

# %% [markdown]
# ![exercicio-matriz.png](data:image/png;base64,...)

# %% [markdown]
# Constra essa matriz com Python, usando uma variavel chamada `cidades`, e em seguida, imprima mensagens com a quantidade de habitantes de Recife, área da cidade de Natal e temperatura média de João Pessoa.

# %%
# Construa seu código AQUI

# %% [markdown]
# ## Parte 3: Estruturas de repetição

# %% [markdown]
# Em muitas situações, desejamos fazer uma mesma ação várias vezes em nossos programas. Para fazer um programa repetir um mesmo código várias vezes, podemos utlizar duas estruturas de repetição: o **for** (do inglês, para) e o **while** (do inglês, enquanto). Observe os exemplos abaixo para entender melhor como esse tipo de estrutura funciona.

# %% [markdown]
# ### **Exemplo 3**: Contando de 1 a 10
#
# O programa abaixo irá imprimir uma mensagem contando os números de 1 a 10. Perceba que, para isso, utilizamos a estrutura de repetição `for`, e em seguida, uma estrutura `range(1, 11)`. Essa última estrutura significa que vamos contar os números dentro de uma certa `condição`, em que essa condição é justamente que os números sejam justamente entre 1 e 10, nem maiores nem menores do que isso.
#
# **E por que utilizamos os valores 0 a 11?**
#
# No Python, ele irá contar até o último valor - 1, então, para que ele consiga contar até 10, é preciso adicionar 1 em seu valor final para ele captar esse número. Se tivéssemos colocado `range(1, 10)`, ele só iria contar até o 9.

# %%
for numero in range(0, 11):
  print('Número ' + str(numero))

# %% [markdown]
# ### **Exemplo 4**: Acertando o valor da senha
#
# Neste exemplo, a estrutura de repetição `while` será utilizada. Ela é utilizada quando não sabemos exatamente quantas vezes queremos repetir o nosso programa. No exemplo anterior, sabíamos que queríamos repetir nosso programa exatamente 10 vezes, para contar de 1 a 10, mas para adivinhar o valor de uma senha, não sabemos quantas vezes o usuário irá errar até finalmente acertá-la. Vejamos o exemplo abaixo para adivinhar uma senha:

# %%
senha_correta = "senha1234"
senha_digitada = input("Digite sua senha: ")

while(senha_correta != senha_digitada):
  print("A senha digitada está incorreta, tente novamente")
  senha_digitada = input("Digite sua senha: ")

print("Senha correta digitada!")

# %% [markdown]
# Enquanto o usuário digitar a senha errada, ele não irá avançar no programa, ficará pedindo para o usuário digitar a senha novamente. Porém, no momento que o usuário digitar `senha1234`, nosso programa verá que a senha está correta, e assim, irá dizer que agora a senha digitada está correta

# %% [markdown]
# ### **Exercício 4**: Mostrando apenas os países da América do Sul com mais de 15 milhões de habitantes
#
# Dessa vez, vamos fazer um exercício já visto anteriormente, mas utilizando estruturas de repetição e acesso de elementos em uma lista. Abaixo, já terão duas listas criadas para você: uma com o nome dos países da América do Sul, chamada `nomes_paises`, e outra com a população em milhões de cada um desses países, chamada `populacao_paises`. Utilizando a estrutura de repetição `for`, imprima apenas os nomes dos países que possuam a população acima de 15 milhões.
#
# *       Argentina: Aproximadamente 45,4 milhões de habitantes.
# *       Bolívia: Aproximadamente 11,8 milhões de habitantes.
# *       Brasil: Aproximadamente 213,9 milhões de habitantes.
# *       Chile: Aproximadamente 19,1 milhões de habitantes.
# *       Colômbia: Aproximadamente 50,3 milhões de habitantes.
# *       Equador: Aproximadamente 17,8 milhões de habitantes.
# *       Guiana: Aproximadamente 790 mil habitantes.
# *       Paraguai: Aproximadamente 7,3 milhões de habitantes.
# *       Peru: Aproximadamente 33,8 milhões de habitantes.
# *       Suriname: Aproximadamente 591 mil habitantes.
# *       Uruguai: Aproximadamente 3,5 milhões de habitantes.
# *       Venezuela: Aproximadamente 28,4 milhões de habitantes.
#
# Então, por exemplo, se a palavra `Argentina` estiver na posição 0 da lista `nomes_paises`, a posição 0 da lista `populacao_paises` terá justamente a quantidade de habitantes da Argentina.
#
# DICA: nesta situação, como nossas listas possuem as informações de 12 países, utilize o `range(0, 12)`

# %%
nomes_paises = ['Argentina', 'Bolívia', 'Brasil', 'Chile', 'Colômbia', 'Equador', 'Guiana', 'Paraguai', 'Peru', 'Suriname', 'Uruguai', 'Venezuela']
populacao_paises = [45.4, 11.8, 213.9, 19.1, 50.3, 17.8, 0.79, 7.3, 33.8, 0.591, 3.5, 28.4]

#Continue o código AQUI

# %% [markdown]
# ## Parte 4: Trabalhando com tabelas - Biblioteca Pandas

# %% [markdown]
# Existem muitas situações do nosso dia-a-dia em que desejamos trabalhar com tabelas para montar gráficos, por exemplo. Nós podemos mexer com tabelas em Python utilizando uma **biblioteca** chamada Pandas.
#
# Em geral, uma biblioteca pode ser entendida como um conjunto de ferramentas extras do Python, para fazer funcionalidades a mais de uma forma mais simples e rápida. Nesse caso, a biblioteca Pandas foi criada justamente para trabalhar de forma muito mais simples com tabelas.

# %% [markdown]
# ### **Exemplo 5**: Lendo uma tabela do Excel com dados do IBGE
#
# Para fazer isso, nós podemos utilizar a biblioteca Pandas. A primeira coisa a fazer é dizer para o Python que nós queremos utilizar essa biblioteca, dando um apelido para ela, `pd`. Isso é feito apenas para que o nome da biblioteca não fique tão grande quando formos utilizar suas funcionalidades.
#
# A próxima etapa consiste em ler os dados da tabela. Existe uma funcionalidade do Pandas chamada `read_excel` (do inglês, ler excel), em que precisamos apenas dizer qual é o nome do arquivo que queremos que seja lido, sendo importante pontuar que ela só funciona para arquivos do excel do tipo `.xlsx`
#
# Por fim, queremos finalmente ver a nossa tabela! Para isso, podemos utilizar a funcionalidade `head()` (do inglês, cabeça), que irá mostrar apenas as 5 primeiras linhas da nossa tabela

# %%
#Importando a biblioteca do pandas
import pandas as pd

#Criando a tabela com os dados do IBGE
dados = pd.read_excel('dados_ibge.xlsx')

#Vendo as 5 primeiras linhas da tabela
dados.head()

# %% [markdown]
# Existem muitas outras coisas que podem ser feitas com uma tabela, mas neste minicurso trataremos apenas esta leitura dos dados. Caso deseje se aprofundar no assunto, o repositório do curso terá links extras para te guiar sobre como aprender a mexer com estas tabelas!

# %% [markdown]
# ## Parte 5 - Desenhando gráficos - Biblioteca Plotly

# %% [markdown]
# Existem muitas situações em que gostaríamos de plotar gráficos a partir de uma tabela para ter informações de uma maneira mais visual. Também é possível fazer isso com o Python, utilizando uma biblioteca chamada Plotly. Ela permite fazer os mais diversos tipos de gráficos com diferentes estilos e funcionalidades. [Este link](https://plotly.com/python/) contém todos os gráficos e funcionalidades disponíveis dessa biblioteca.

# %% [markdown]
# ### **Exemplo 6**: Plotando um gráfico de barras com os dados do IBGE
#
# A primeira parte, que já foi feita anteriormente e só será repetida, é justamente realizar a leitura dos dados do Excel e organizá-los em uma tabela. Em seguida, precisamos pegar esses dados, e utilizando a biblioteca Plotly, montar o gráfico desejado, que no nosso caso, é um gráfico de barras.
#
# Dentro da funcionalidade de montar um gráfico de barras, temos que informar quais são os dados que vamos querer plotar (ou seja, colocar nossa tabela inteira), e depois especificar quais valores irão ficar no eixo x e no eixo y.

# %%
#Importando a biblioteca do pandas e do plotly
import pandas as pd
import plotly.express as px

#Criando a tabela com os dados do IBGE
dados = pd.read_excel('dados_ibge.xlsx')

#Criando a figura do gráfico a partir da tabela
fig = px.bar(dados, x='Ano', y='População')

#Mostrando a figura na tela
fig.show()

# %% [markdown]
# ### **Exemplo 7**: Melhorando nosso gráfico
#
# Nosso gráfico foi plotado, entretanto, tem certas coisas que poderiam ser melhoradas... Ele não possui um título, e só consigo ver os valores exatos da população ao colocar meu mouse em cima da barra. Também queria poder mudar as cores da barra. Com o plotly, tudo isso é possível!
#
# Para isso, precisamos apenas especificar esses valores com algumas funcionalidades a mais, veja no exemplo abaixo. O que mudou? Entre algumas mudanças, temos:
#
# *   **title**: do inglês, título, ou seja, será o título do nosso gráfico
# *   **color_discrete_sequence**: do inglês, sequência discreta de cores. Pode parecer um nome um pouco confuso, mas é aqui que vamos definir a cor das barras do nosso gráfico. Podemos escrever o nome da cor em inglês, ou utilizar um código hexadecimal de cores.
# *   **text**: do inglês, texto, ou seja, irá mostrar um texto em cada uma das barras do nosso gráfico. No nosso caso, queremos mostrar o texto com a população brasileira em cada um dos anos.
# *   **text_position=outside**: do inglês, posição do texto = fora. Isso é apenas um recurso de estilização para dizer que queremos colocar o texto fora da barra.

# %%
#Importando a biblioteca do pandas e do plotly
import pandas as pd
import plotly.express as px

#Criando a tabela com os dados do IBGE
dados = pd.read_excel('dados_ibge.xlsx')

#Criando a figura do gráfico a partir da tabela
fig = px.bar(dados, x='Ano', y='População', title='Evolução da população brasileira conforme dados do IBGE',
             color_discrete_sequence=['#586F94'], text='População')

#Mostrando a figura na tela
fig.update_traces(textposition='outside')
fig.show()

# %% [markdown]
# ### **Exercício 5**: Plotando um gráfico de linhas
#
# Que tal fazermos algumas mudanças em nosso gráfico? Mude os códigos anteriores para, ao invés de plotar um gráfico de barras, desenhar um gráfico de linhas. Fique à vontade para fazer outras mudanças no gráfico, como cores e estilo. Tudo isso pode ser verificado consultando a documentação da biblioteca Plotly [aqui](https://plotly.com/python/)

# %%
# Escreva seu código AQUI
