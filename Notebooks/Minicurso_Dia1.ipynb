# %% [markdown]
# # Introdução à programação com Python 💻
#
# ### **Dia 1 - Conceitos básicos**
#
# Este notebook tem como objetivo dar os primeiros passos com a linguagem de programação **Python**, fazendo códigos na prática para começar a entender os conceitos básicos da programação. Aqui, iremos fazer exercícios dos seguintes conteúdos:
#
# *   Variáveis
# *   Lendo e imprimindo valores
# *   Operações aritméticas
# *   Operações booleanas
# *   Estruturas condicionais

# %% [markdown]
# ## Introdução ao Google Colab

# %% [markdown]
# O **Google Colab** é uma plataforma que permite desenvolver códigos em Python, e armazená-los na nuvem em sua conta do **Google Drive**. Assim, aonde quer que você esteja, basta acessar sua conta do Google para ter acesso a todos os notebooks desenvolvidos durante o curso
#
# Podem ser criadas células de **texto**, como essa, para explicar conceitos, por exemplo, ou então, células de código, para escrever nossos programas em **Python**. Para criar uma nova célula, basta criar nos botões `+ Código` ou `+ Texto` no canto superior esquerdo.
#
# Ao terminar de escrever um código, para podermos vê-lo funcionando, basta clicar no botão Play (como esse: ▶) localizado no canto esquerdo da célula.

# %% [markdown]
# ## Parte 1: Variáveis

# %% [markdown]
# As variáveis são espaços na memória do computador para guardarmos informações. Basicamente, utilizando as variáveis para guardar uma informação que vamos querer utilizar depois em nossos programas.
#
# Leve em consideração os dados de uma padaria, por exemplo. Podemos querer guardar informações sobre o nome de um produto, a quantidade produzida em um determinado dia, preço individual deste produto, ou até mesmo se houve problemas durante a sua produção ou não. Para isso, poderíamos criar uma variável para armazenar cada uma destas informações

# %% [markdown]
# ### **Exemplo 1**: Produtos de uma padaria
#
# Neste exercício, você deve apenas tentar entender o código abaixo. A imagem mostra informações dos produtos de uma padaria:
#
# ![img-tipos-variaveis.png](data:image/png;base64,...)

# %% [markdown]
# Na célula de código abaixo, verifique como as informações são armazenadas nas variáveis:

# %%
nome_do_produto = 'Bolo de chocolate'
quantidade_produzida = 50
preco_individual = 22.5
problemas_producao = False

# %% [markdown]
# Percebe que a escrita das variáveis é um pouco diferente? Nelas, não podemos ter espaço nem caracteres especiais, como acentos ou ç. Para criar o nome de uma variável, só podemos usar letras, números e o símbolo `_`.
#
# Você também pode perceber que existem vários **tipos** de variáveis. Elas podem ser:
#
# *   **Números inteiros**: números como -1, 0, 1, 2, 3... Essas variáveis, na programação, se chamam `int`;
# *   **Números fracionários**: são os números "com vírgula", como 3,14, por exemplo. Na programação, eles se chamam `float`, e é preciso usar um `.` ao invés da `,` para que o computador possa entender esse número;
# *   **Booleanos**: são valores que significam se algo é verdadeiro (na programação, chamamos de `True`) ou falso (na programação, chamamos de `False`). Esse tipo de variável pertence à classe `bool`;
# *  **Palavras e caracteres**: são todos os textos que queremos escrever, e na programação, eles são chamados de `string`. Para guardar um texto em uma variável, é preciso usar `" "` ou `' '`.
#
# Por fim, a última coisa importante: para armazenar um valor de uma variável, sempre usamos a seguinte estrutura:
#
# `nome_da_variável = valor`
#
# O símbolo `=` é usado justamente para **atribuir** um valor a uma variável.

# %% [markdown]
# ### **Exercício 1**: Informações de um estudante
#
# Com base nas informações abaixo, crie variáveis para armazenar as informações de um estudante da UFRN:
#
# ![exercicio1-minicurso.png](data:image/png;base64,...)

# %%
# Escreva o seu código AQUI

# %% [markdown]
# ## Parte 2: Lendo e imprimindo valores

# %% [markdown]
# Em muitas situações, queremos poder fornecer uma informação para o computador, para que ele possa processar a informação, e depois, exibir o resultado em sua tela. Para fazer isso, podemos utilizar duas funções básicas:
#
# *   `print()`: do inglês, significa imprimir, ou seja, vamos imprimir informações na tela do computador
# *   `input()`: do inglês, significa entrada, ou seja, vamos fornecer dados de entrada para que eles sejam processados pelo computador

# %% [markdown]
# ### **Exemplo 2**: imprimindo meu nome na tela
#
# Rode o código abaixo e veja o que acontece:

# %%
nome = input("Qual é o seu nome?")
print('Olá, ' + nome + '!') 
print(f'Olá {nome}!')

# %% [markdown]
# Nesse código, a primeira coisa que vai acontecer é uma entrada de dados. Ou seja, o computador vai ficar esperando que você digite o seu nome, para que ele possa fazer alguma operação com essa informação. Para isso, é utilizada a função `input()` com um texto, sendo esse texto a pergunta a ser feita para o usuário
#
# Depois, usamos a função `print()` para mostrar uma informação na tela. Note que uma parte do texto sempre será a mesma, e a única coisa que mudará, será o nome da pessoa, guardado na variável `nome`. Para isso, podemos combinar os textos utilizando o caractere `+`, como se estivéssemos juntando vários textos em um só. Então, por exemplo, se a pessoa se chamar `Joana`, teremos a seguinte operação:
#
# `'Olá, '` + nome + `'!'` &#8594; `'Olá, '` + `'Joana'` + `'!'` &#8594; `'Olá, Joana!'`
#
# Outro jeito de utilizar a função print é com a letra `f` logo no início, e colocar as variáveis entre `{}`. O resultado será o mesmo!

# %% [markdown]
# ### **Exercício 2**: Perguntando seus favoritos
#
# Faça um programa em que o computador te pergunte 3 coisas:
#
# *   Qual é a sua cor favorita? (Ex.: rosa)
# *   Qual é seu animal favorito? (Ex.: coelho)
# *   Qual é seu filme favorito? (Ex.: Harry Potter)
#
# Ao final, deve-se exibir a mensagem `Minha cor favorita é rosa, meu animal favorito é coelho e meu filme favorito é Harry Potter`

# %%
# Escreva seu código AQUI

# %% [markdown]
# ## Parte 3: Operações aritméticas

# %% [markdown]
# O computador é muito bom em resolver operações matemáticas. Algumas delas são:
#
# *   **Soma**: usa-se o símbolo `+`;
# *   **Subtração**: usa-se o símbolo `-`;
# *   **Multiplicação**: usa-se o símbolo `*`;
# *   **Divisão**: usa-se o símbolo `/`;
# *   **Potência**: usa-se o símbolo `**`. Essa operação, na matemática, irá multiplicar um número várias vezes. Então, a operação de potência 4³ é o mesmo que fazer 4x4x4;
# *   **Resto de divisão**: usa-se o símbolo `%`. Ao dividir 5 por 2, por exemplo, obtemos o valor 2, mas ficamos com o valor 1 sobrando. Essa operação seria justamente para computar o valor 1.

# %% [markdown]
# ### **Exemplo 3**: Praticando operações aritméticas
#
# Observe o código abaixo em que são computadas algumas operações. Você consegue entender o que está acontecendo? Antes de rodar a célula de código, tente escrever no comentário qual é o resultado esperado

# %%
a = 2
b = 10
c = 5
d = 3

resultado1 = a+a # Valor esperado = 
resultado2 = b-a # Valor esperado = 
resultado3 = b*c # Valor esperado = 
resultado4 = b/c # Valor esperado = 
resultado5 = b%d # Valor esperado = 
resultado6 = a**d # Valor esperado = 

print(f'Valor do primeiro resultado: {resultado1}')
print(f'Valor do segundo resultado: {resultado2}')
print(f'Valor do terceiro resultado: {resultado3}')
print(f'Valor do quarto resultado: {resultado4}')
print(f'Valor do quinto resultado: {resultado5}')
print(f'Valor do sexto resultado: {resultado6}')
# Out:
# Valor do primeiro resultado: 4
# Valor do segundo resultado: 8
# Valor do terceiro resultado: 50
# Valor do quarto resultado: 2.0
# Valor do quinto resultado: 1
# Valor do sexto resultado: 8

# %% [markdown]
# ### **Exercício 3**: calculando a densidade demográfica de uma cidade
#
# Para calcular a densidade demográfica de uma cidade, estado ou país, podemos utilizar a seguinte fórmula:
# $Densidade= \frac{Quantidade\:de\:Habitantes}{Area}$
#
# Assim, crie o programa em que o usuário forneça valores para a `quantidade_habitantes`, `area` e `nome` de uma cidade. Ao final, imprima uma mensagem com o seguinte formato: `A cidade de Natal possui 4805.24 habitantes/km2`.

# %%
# escreva seu código AQUI

# %% [markdown]
# ## Parte 4: Operações booleanas

# %% [markdown]
# Ao contrário das operações aritméticas, que retornam valores de números, as operações booleanas retornam respostas de verdadeiro (`True`) ou falso (`False`). Dessa forma, nós podemos formar expressões boolenas utilizando vários símbolos, como pode ser visto abaixo:
#
# ![img-booleanos.png](data:image/png;base64,...)

# %% [markdown]
# ### **Exemplo 4**: Compreendendo as expressões boolenas
#
# Observe o código abaixo, e escreva no comentário ao lado se ele vai retornar um valor verdadeiro ou falso. Depois, rode a célula de código abaixo para verificar se suas respostas estão corretas

# %%
a = 2
b = 10
c = 5
d = 2

resultado1 = a == d # Valor esperado = 
resultado2 = b != c # Valor esperado = 
resultado3 = d > b # Valor esperado = 
resultado4 = d >= a # Valor esperado = 
resultado5 = c < d # Valor esperado = 
resultado6 = c <= b # Valor esperado = 

print(f'Valor do primeiro resultado: {resultado1}')
print(f'Valor do segundo resultado: {resultado2}')
print(f'Valor do terceiro resultado: {resultado3}')
print(f'Valor do quarto resultado: {resultado4}')
print(f'Valor do quinto resultado: {resultado5}')
print(f'Valor do sexto resultado: {resultado6}')

# %% [markdown]
# O que vimos anteriormente foram as **expressões boolenas**. Já as **operações boolenas** podem envolver 3 tipos de operações:
#
# *   **E**: todas as expressões precisam ser verdadeiras para o resultado final ser verdadeiro. Na programação, usamos a palavra `and` para esta operação.
# *   **OU**: apenas uma expressão precisa ser verdadeira para o resultado final ser verdadeiro. Na programação, usamos a palavra `or` para esta operação.
# *   **NOT**: se algo é verdade, se tornará falso, e se algo é falso, se tornará verdade. Usamos a expressão `not` na programação para esta operação.

# %% [markdown]
# ### **Exemplo 5**: Compreendendo as operações booleanas
#
# Abaixo, serão apresentadas informações sobre as temperaturas de algumas cidades brasileiras. Tente entender o programa e verificar se seu resultado final será verdadeiro ou falso.

# %%
temperatura_natal = 27.3
temperatura_brasilia = 20.5
temperatura_sao_paulo = 21.5

afirmacao1 = temperatura_natal > temperatura_brasilia # Isso é verdade!
afirmacao2 = temperatura_sao_paulo < temperatura_brasilia # Isso é falso!

print(f'Todas as afirmações estão corretas? Resposta = {afirmacao1 and afirmacao2}') # Qual será esse resultado?
print(f'Pelo menos uma afirmação está correta? Resposta = {afirmacao1 or afirmacao2}') # Qual será esse resultado?
print(f'Qual é o contrário da afirmação 1? Resposta = {not afirmacao1}') # Qual será esse resultado?

# %% [markdown]
# ### **Exercício 4:** verificando se um aluno da UFRN é aprovado ou reprovado em uma matéria
#
# Para ser aprovado na UFRN, a média de um aluno deve ser maior ou igual a 5.0, e a sua presença deve ser maior ou igual a 75%. Escreva um programa que receba o valor da `media` de um aluno (esse número pode ir de 0 a 10) e receba o valor da `frequencia` do aluno (esse número pode ir de 0 a 100). Ao final, imprima na tela se o aluno irá passar na matéria (valor `True`) ou se ele será reprovado (valor `False)`
#
# *   Exemplo 1: se o aluno tiver média 6.0 e frequência 50, deve-se imprimir `False`
#
# *   Exemplo 2: se o aluno tiver média 8.5 e frequência 90, deve-se imprimir `True`
#
# *   Exemplo 3: se o aluno tiver média 4.0 e frequência 50, deve-se imprimir `False`

# %%
# Escreva seu código AQUI

# %% [markdown]
# ## Parte 5: Estruturas condicionais
#
# As estruturas condicionais são utilizadas quando queremos que nosso programa tome caminhos diferentes, dependendo das informações que o usuário digitar, por exemplo. A figura abaixo mostra um exemplo de uma estrutura condicional:
#
# ![Dia1-MinicursoPython.png](data:image/png;base64,...)

# %% [markdown]
# Para utilizar uma estrutura condicional no Python, utilizamos os comandos `if` (do inglês, se) e `else` (do inglês, se não). Abaixo, temos um exemplo de código básico:
#
# ```
# if(condição):
#    faça uma coisa
# else:
#   faça outra coisa
# ```
#
# Se a minha condição for atendida, o programa irá fazer uma coisa, se não, ele irá fazer outra coisa diferente.

# %% [markdown]
# ### **Exemplo 6**: determinando se o dia está quente ou não (programa 1)
#
# Nessa primeira situação, vamos considerar que uma temperatura acima de 30°C determina que um dia é quente, e qualquer valor abaixo disso, determina que um dia é frio. Observe o código abaixo e mude os valores da variável `temperatura` para ver como ele se comporta

# %%
temperatura = 32
if(temperatura > 30):
  print('Hoje o dia está quente!')
else:
  print('Hoje o dia está frio!')

# %% [markdown]
# ### **Exemplo 7**: determinando se o dia está quente ou não (programa 2)
#
# Às vezes nós queremos verificar várias condições diferentes. Por exemplo, quero fazer um programa que diga as seguintes informações de um dia com base em sua temperatura:
#
# *   Se a temperatura estiver acima de 30°C, o dia está muito quente
# *   Se a temperatura estiver entre 20°C e 30°C, o dia está agradável
# *   Se a temperatura estiver abaixo de 20°C, o dia está muito frio
#
# Para isso, nós podemos acrescentar uma outra estrutura do python, o `elif` (do inglês, se não se). Veja a estrutura básica abaixo e depois analise o código, trocando os valores da variável temperatura para ver como ele se comporta:
#
# ```
# if(condição 1):
#   faça uma coisa
# elif(condição 2):
#   faça outra coisa
# else:
#   faça outra coisa diferente
# ```

# %%
temperatura = 25
if(temperatura > 25):
  print('Hoje o dia está muito quente!')
elif(temperatura >= 20 and temperatura <= 30):
  print('Hoje o dia está agradável')
else:
  print('Hoje o dia está muito frio!')

# %% [markdown]
# ### **Exercício 5**: verificando se um aluno foi aprovado ou não
#
# Na UFRN, desconsiderando a questão da frequência, existem 3 situações para um aluno em uma disciplina, considerando que são aplicadas 3 provas em um semestre:
#
# *   Se a média final for maior ou igual a 7.0, o aluno é **aprovado**
# *   Se a média final for maior ou igual a 5.0, mas menor do que 7.0, o aluno é **aprovado por nota**
# *   Se a média final for menor do que 5.0, o aluno é **reprovado**
#
# Faça um programa que receba os valores de 3 notas de um aluno, calcule sua média, e ao final, imprima uma das seguintes mensagens:
#
# *   Se ele for aprovado: `Parabéns, você foi aprovado!`
# *   Se ele for aprovado por nota: `Você foi aprovado por nota!`
# *   Se ele for reprovado: `Infelizmente, você foi reprovado :(`
#
# DICA: para calcular a média dos alunos, faça o seguinte cálculo:
# $media = \frac{(nota_1 + nota_2 + nota_3)}{3}$
#
# É muito importante colocar os parênteses para que o computador entenda que você primeiro quer somar os valores das notas para depois dividir por 3

# %%
# Escreva seu código AQUI
